# %% [markdown]
# # Teclov : Visualising Time Series Data
#
# In the section, we will explore ways to visualise data gathered over time. We will:
# - Plot simple time series plots
# - Derive variables such as month and year and use them for richer visualisations

# %%
# loading libraries and reading the data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# set seaborn theme if you prefer
sns.set(style="white")

# read data
market_df = pd.read_csv("./global_sales_data/market_fact.csv")
customer_df = pd.read_csv("./global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("./global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("./global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("./global_sales_data/orders_dimen.csv")

# %% [markdown]
# ## Visualising Simple Time Series Data
#
# Let's say you want to visualise numeric variables such as ```Sales```, ```Profit```, ```Shipping_Cost``` etc. over time.

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %% [markdown]
# Since the ```Order_Date``` variable is in the orders dataframe, let's merge it.

# %%
# merging with the Orders data to get the Date column
df = pd.merge(market_df, orders_df, how='inner', on='Ord_id')
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 4  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID  Order_Date  \
# 0   -30.51           3.60                 0.56     36262  27-07-2010
# 1  1148.90           2.50                 0.59     36262  27-07-2010
# 2   -47.64           6.15                 0.37     36262  27-07-2010
# 3     4.56           0.93                 0.54     20513  07-07-2009
# 4   729.34          14.30                 0.37     39682  09-11-2010
#
#   Order_Priority
# 0  NOT SPECIFIED
# 1  NOT SPECIFIED
# 2  NOT SPECIFIED
# 3           HIGH
# 4         MEDIUM

# %%
# Now we have the Order_Date in the df
# It is stored as a string (object) currently
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
#  10  Order_ID             8399 non-null   int64
#  11  Order_Date           8399 non-null   object
#  12  Order_Priority       8399 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 853.2+ KB

# %% [markdown]
# Since ```Order_Date``` is a string, we need to convert it into a ```datetime``` object. You can do that using ```pd.to_datetime()```.

# %%
# Convert Order_Date to datetime type
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# Order_Date is now datetime type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
#  10  Order_ID             8399 non-null   int64
#  11  Order_Date           8399 non-null   datetime64[ns]
#  12  Order_Priority       8399 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 853.2+ KB
# C:\Users\Simon\AppData\Local\Temp\ipykernel_11284\220854924.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %% [markdown]
# Now, since on each day, multiple orders were placed, we need to aggregate ```Sales``` using a metric such as mean, median etc., and then create a time series plot.
#
# We will group by ```Order_Date``` and compute the sum of ```Sales``` on each day.

# %%
# aggregating total sales on each day
time_df = df.groupby('Order_Date')['Sales'].sum()
print(time_df.head())

print(type(time_df))
# Out:
# Order_Date
# 2009-01-01     1052.8400
# 2009-01-02    11101.8700
# 2009-01-03    31997.8555
# 2009-01-04     1254.2500
# 2009-01-05    39734.4040
# Name: Sales, dtype: float64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# We can now create a time-series plot using ```sns.tsplot()```.

# %%
# time series plot

# figure size
plt.figure(figsize=(16, 8))

# tsplot
#sns.tsplot(data=time_df) #depracated tsplot: use lineplot instead

#lineplot
sns.lineplot(data=time_df) #depracated tsplot: use lineplot instead
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Using Derived Date Metrics for Visualisation
#
# It is often helpful to use derived variables from date such as month and year and using them to identify hidden patterns.

# %%
# extracting month and year from date

# extract month
df['month'] = df['Order_Date'].dt.month

# extract year
df['year'] = df['Order_Date'].dt.year

df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 4  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID Order_Date  \
# 0   -30.51           3.60                 0.56     36262 2010-07-27
# 1  1148.90           2.50                 0.59     36262 2010-07-27
# 2   -47.64           6.15                 0.37     36262 2010-07-27
# 3     4.56           0.93                 0.54     20513 2009-07-07
# 4   729.34          14.30                 0.37     39682 2010-11-09
#
#   Order_Priority  month  year
# 0  NOT SPECIFIED      7  2010
# 1  NOT SPECIFIED      7  2010
# 2  NOT SPECIFIED      7  2010
# 3           HIGH      7  2009
# 4         MEDIUM     11  2010

# %% [markdown]
# Now you can plot the average sales across years and months.

# %%
# grouping by year and month
df_time = df.groupby(["year", "month"]).Sales.mean()
df_time.head()
# Out:
# year  month
# 2009  1        2315.259908
#       2        2187.372609
#       3        2225.020157
#       4        2286.491174
#       5        1264.535923
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 6))
# time series plot
#sns.tsplot(df_time) #deprecated tsplot
sns.lineplot(df_time)
plt.xlabel("Time")
plt.ylabel("Sales")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File lib.pyx:2374, in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 plt.figure(figsize=(8, 6))
#       2 # time series plot
#       3 #sns.tsplot(df_time) #deprecated tsplot
# ----> 4 sns.lineplot(df_time)
#       5 plt.xlabel("Time")
#       6 plt.ylabel("Sales")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:423, in _LinePlotter.plot(self, ax, kws)
#     415 # TODO How to handle NA? We don't want NA to propagate through to the
#     416 # estimate/CI when some values are present, but we would also like
#     417 # matplotlib to show "gaps" in the line when all values are missing.
#    (...)
#     420
#     421 # Loop over the semantic subsets and add to the plot
#     422 grouping_vars = "hue", "size", "style"
# --> 423 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     425     if self.sort:
#     426         sort_vars = ["units", orient, other]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1028, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#    1023 grouping_vars = [
#    1024     var for var in grouping_vars if var in self.variables
#    1025 ]
#    1027 if from_comp_data:
# -> 1028     data = self.comp_data
#    1029 else:
#    1030     data = self.plot_data
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1126, in VectorPlotter.comp_data(self)
#    1121     if var in self.var_levels:
#    1122         # TODO this should happen in some centralized location
#    1123         # it is similar to GH2419, but more complicated because
#    1124         # supporting `order` in categorical plots is tricky
#    1125         orig = orig[orig.isin(self.var_levels[var])]
# -> 1126 comp = pd.to_numeric(converter.convert_units(orig))
#    1127 if converter.get_scale() == "log":
#    1128     comp = np.log10(comp)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:222, in to_numeric(arg, errors, downcast, dtype_backend)
#     220 coerce_numeric = errors not in ("ignore", "raise")
#     221 try:
# --> 222     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa: E501
#     223         values,
#     224         set(),
#     225         coerce_numeric=coerce_numeric,
#     226         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     227         or isinstance(values_dtype, StringDtype)
#     228         and not values_dtype.storage == "pyarrow_numpy",
#     229     )
#     230 except (ValueError, TypeError):
#     231     if errors == "raise":
#
# File lib.pyx:2416, in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type at position 0

# %% [markdown]
# There is another way to visualise numeric variables, such as ```Sales```, across the year and month. We can pivot the ```month``` column to create a wide-format dataframe, and then plot a heatmap.

# %%
# Pivoting the data using 'month' 
year_month = pd.pivot_table(df, values='Sales', index='year', columns='month', aggfunc='mean')
year_month.head()

# %% [markdown]
# You can now create a heatmap using ```sns.heatmap()```.

# %%
# figure size
plt.figure(figsize=(12, 8))

# heatmap with a color map of choice
sns.heatmap(year_month, cmap="YlGnBu")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       2 plt.figure(figsize=(12, 8))
#       4 # heatmap with a color map of choice
# ----> 5 sns.heatmap(year_month, cmap="YlGnBu")
#       6 plt.show()
#
# NameError: name 'year_month' is not defined

# %% [markdown]
# ### Addtional Reading on Time Series Plots and Heatmaps
#
# 1. <A href="https://seaborn.pydata.org/generated/seaborn.heatmap.html">Seaborn heatmaps (documentation)</a>
