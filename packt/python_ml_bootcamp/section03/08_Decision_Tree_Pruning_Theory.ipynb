# %% [markdown]
# #### Pruning
#
# - regularization technique for decision trees
# - control growth of trees by reducing number of leafs
# - idea of pruning: after our tree has been trained, we can then go back and reduce the number of leafs to then have a shorter tree (reducing overfitting)
# - minimal cost complexity pruning (sklearn), tries to mimize the following equation:
# - ![grafik.png](attachment:fdeee4e2-7632-4d4c-ab18-672abbee09ae.png)
# - alpha is the free parameter, R(T) comes from the trained model
# - pruning algorithm tries to find the the balance of the total misclassification rate in the tree balanced against the total number of leaf nodes that we have
# - bigger alpha means the total number of leaf nodes have a larger impact (ride hand side of the equation) otherwise a smaller alpha will increase the left hand side
# - ![grafik.png](attachment:8189c298-b315-454f-97e4-a87ee4da30da.png)
# - use pruning after trees have been built by balancing the misclassifications against the actual size of the tree => reduce/eliminate overfitting, better generalization
