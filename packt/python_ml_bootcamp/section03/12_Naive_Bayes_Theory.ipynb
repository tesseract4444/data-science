# %% [markdown]
# #### 01 Bayes Theorem
#
# - Naive assumption
#     - feature independence
#     - simplyfied formula to line 2
# - Denominator is a constant given from our training data
# - P(y) is class occurences & like P(xi|y) we can get it from training data
# - left hand side of the equation is our prediction
# - we get all the right hand side components from our training data directly
#
# ![grafik.png](attachment:2293dc14-4c4d-45aa-87c2-81373dafdcde.png)

# %% [markdown]
# ------------------

# %% [markdown]
# #### 02 Additive Smoothing
#
# - when, in testing or validation, we get a unseen value of a feature
# - n = number of features
# - N = number of observations
# - xi number of occurences of value i
#
# ![grafik.png](attachment:3e6704bc-1d79-41d6-ac7d-f936a400a51c.png)

# %% [markdown]
# ------------------------

# %% [markdown]
# #### 03 Naive Bayes Applications
#
# - requires only small amounts of training data to work properly
# - performs well on small training sets
# - spam classification
# - predict_proba not particularly accurate

# %% [markdown]
# -----------------------------

# %% [markdown]
# #### 04 Gaussian Naive Bayes
#
# - assumes features are distributed in a Gaussian nature within each class (and we make one of those for every single class)
# - mean and standard deviation of x_i in each class, y
# - get probability based on gaussian distribution
#
# ![grafik.png](attachment:df1de4bc-e953-4aaa-8eb8-6fd6eb99af86.png)

# %% [markdown]
# ----------------------

# %% [markdown]
# #### 05 Other Naive Bayes models
#
# - make different assumptions about p(xi|y) =
# - multinomial, Bernoulli
# - Multinomial formula:
#
# ![grafik.png](attachment:279bd065-fe27-4cd1-bc40-aa54e601543b.png)

# %% [markdown]
# ------------------------

# %% [markdown]
# #### 06 How our models would look like
#
# - Gaussian Naive Bayes
#
# ![grafik.png](attachment:f9a3723d-161d-44a0-b4db-e9799f36980b.png)
#
# - Multinomial
#
# ![grafik.png](attachment:59a75574-b2d0-4a14-bb0f-907f6b2f4f36.png)
