# %% [markdown]
# #### SVM Regression
#
# - SVM classification
#     - "keep the street wide and clean"
#     - finding a separation
#     - ![grafik.png](attachment:bd70c8ea-9c5a-42e1-bc03-4eb25dbb9fc1.png)
#     - keep only minimal margin violations
#
# </br>
#
# - SVM regression
#     - get the street as narrow as possible and try to fit as many instances within it
#     - width controlled by epsilon, larger = larger street
#     - squared-epsilon insensitive loss
#     - anything inside will not change our support vector regressor
#     - keep the margin violations as high as possible
#     - anything within the margin does not contribute to the loss (within epsilon)
#     - ![grafik.png](attachment:0412714c-85c0-40cf-8414-0ce85a5c6a85.png)
#
# </br>
#
# - additional parameter
#     - shrinking - can help improve training times when model has many iterations by effectively removing some observations during training that likely won't contribute to the loss => shrinking is good but it is not as useful as reducing the tolerance
#     - not as effective as e.g. just making error tolerance larger
