# %% [markdown]
# #### DT Regression
#
# - classification
#     - create clean splits
#     - RT: make a clean split at each node with the lowest impurity (that does not work for DT regression anymore)
#     - ![grafik.png](attachment:62ec1caa-c739-4485-8861-653748461646.png)
#     - the tree looks like this:
#     - ![grafik.png](attachment:aab8f2b9-6e5f-45e8-a464-44b67e09686e.png)
#
# </br>
#
# - regression
#     - split to minimize MSE/MAE (looking for how much each value differs from the mean value)
#     - for each node, n
#     - formula (N=total_number_of_parent_nodes):
#     - ![grafik.png](attachment:ddf81279-48c0-41d8-ace4-56d4cb2f78e8.png)
#     - graph:
#     - ![grafik.png](attachment:8bc0cec2-1a55-4dc7-827e-7bdc00ad1bf5.png)
#     - now depth 2 (not ideal because it's heavily underfit):
#     - ![grafik.png](attachment:02b9aa8b-3b0f-4b11-a1d6-dd850ec1d042.png)
#     - actual tree looks like this (no gini but MSE instead, value is the average value of all values in that leaf):
#     - ![grafik.png](attachment:001a0eff-0ec9-4580-a3d0-fe7308023132.png)
#
# </br>
#
# - stil prone to overfitting when left to grow uncontrolled (not too much growing)
# - ![grafik.png](attachment:74f4afd5-5e4c-45e4-a574-47d3214160c5.png)
# - Random Forest: reduce the depth tremendously
