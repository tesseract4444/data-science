# %% [markdown]
# #### Loading Tabular Data File

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("titanic.csv")

# %%
print(os.getcwd()) #call directory
# Out:
# /home/sid/packt_video_courses/ml_for_absolute_beginners_level2

# %%
os.listdir() #list directory
# Out:
# ['03_introduction_to_the_pandas_library.ipynb',
#  '04_loading_data_into_a_dataframe.ipynb',
#  '.ipynb_checkpoints',
#  'titanic.csv',
#  '02_python_fundamentals_for_data_science.ipynb']

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# #### Adjusting the Loading Parameters

# %%
df = pd.read_csv("titanic.csv", header=None) #header=None removes the names of the columns

# %%
#df = pd.read_csv("titanic.csv", header=None, prefix="col-") #only for files without header

# %%
#col_names =["a1", "a2", "a3", "a4"]
#df = pd.read_csv("titanic.csv", header=None, names=col_names) #only for files without header

# %%
df.index #891 rows plus header
# Out:
# RangeIndex(start=0, stop=892, step=1)

# %%
df = pd.read_csv("titanic.csv", index_col=3) 
#names are now used as an index

# %%
df
# Out:
#                                                     PassengerId  Survived
# Name
# Braund, Mr. Owen Harris                                       1         0  \
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age
# ...

# %%
df = pd.read_csv("titanic.csv", header=0, usecols=[0,1,2,3,4]) 
#usecols: only selects specific columns

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
df = pd.read_csv("titanic.csv", header=0)

# %%
df.dtypes #shows types within the .csv file
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df = pd.read_csv("titanic.csv", header=0, dtype={"Survived":"bool"}) 
#checks true-false values

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1     False       3  \
# 1              2      True       1
# 2              3      True       3
# 3              4      True       1
# 4              5     False       3
# ..           ...       ...     ...
# 886          887     False       2
# 887          888      True       1
# 888          889     False       3
# 889          890      True       1
# 890          891     False       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived          bool
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1     False       3  \
# 1            2      True       1
# 2            3      True       3
# 3            4      True       1
# 4            5     False       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Previewing the DataFrame

# %%
df = pd.read_csv("titanic.csv", header=0)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns #show column names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.values #show all values in the df
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape #shows (rows, columns)
# Out:
# (891, 12)

# %%
df.info() #list with information about all columns, shows missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(20) #first 20 rows
# Out:
#     PassengerId  Survived  Pclass
# 0             1         0       3  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp
# 0                             Braund, Mr. Owen Harris    male  22.0      1  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.tail(5) #last 5 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 886          887         0       2                     Montvila, Rev. Juozas  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.count() #shows amount of entries in each column
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["Sex"].unique() #all names of values
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].value_counts() #counts most frequent elements in "Embarked"
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Sex"].value_counts(normalize=True) #shows relative frequency instead of absolute values (as shown in value_counts)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
df2 = df.T #T=Transpose: switches rows and columns

# %%
df2
# Out:
#                                  0
# PassengerId                        1  \
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1
# PassengerId                                                  2  \
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %% [markdown]
# #### Using Summary Statistics

# %%
df = pd.read_csv("titanic.csv", header=0) #header=None removes the names of the columns

# %%
df["Age"].min() #display minimum age
# Out:
# 0.42

# %%
df["Age"].mean() #mean (mittelwert)
# Out:
# 29.69911764705882

# %%
df[["Age", "Fare"]].mean() #mean age and fare (fare=ticketpreis)
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
df["Survived"].sum() #sum of all survived passengers
# Out:
# 342

# %%
df["Fare"].sum() #sum of all the fares
# Out:
# 28693.9493

# %%
df["Fare"].max() #max of all the fares
# Out:
# 512.3292

# %%
df_select = df[["PassengerId", "Survived", "Pclass", "Age","SibSp", "Parch", "Fare"]]
#accessing multiple data

# %%
df_select.quantile(0.8) #maxima of 80 percent of all passengers
# Out:
# PassengerId    713.0000
# Survived         1.0000
# Pclass           3.0000
# Age             41.0000
# SibSp            1.0000
# Parch            1.0000
# Fare            39.6875
# Name: 0.8, dtype: float64

# %%
df_select.max() #maxima of all passengers
# Out:
# PassengerId    891.0000
# Survived         1.0000
# Pclass           3.0000
# Age             80.0000
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %%
df.describe() #overview of all important statistics
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["Age"].describe() #only statistics about age
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### The Concept of Method Chaining

# %%
df.isnull() #returns a dataframe displaying missing values as a boolean
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket
# 0          False     False   False  False  False  False  False  False   False  \
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df_temp = df.isnull() #shows amount of 0 values

# %%
df_temp.sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum() #alternative
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
type(df.isnull().sum())
# Out:
# pandas.core.series.Series

# %%
df.isnull().sum().sum() #sum of all
# Out:
# 866

# %%
df.dropna() #removes all 0 values
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()["Age"].mean()
# Out:
# 35.6744262295082

# %%
df["Age"].mean() #original data (still containing 0 values)
# Out:
# 29.69911764705882

# %%
df.sort_values("Age", ascending=False).head(10) #sort all values by age
# Out:
#      PassengerId  Survived  Pclass                                  Name
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson  \
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                      Duane, Mr. Frank
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0       27042  30.0000   A23        S
# ...

# %%
df.sort_values("Age", ascending=False)[["Name",  "Age"]].head(10) #sort name values by age
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0
# 851                   Svensson, Mr. Johan  74.0
# 493               Artagaveytia, Mr. Ramon  71.0
# 96              Goldschmidt, Mr. George B  71.0
# 116                  Connors, Mr. Patrick  70.5
# 672           Mitchell, Mr. Henry Michael  70.0
# 745          Crosby, Capt. Edward Gifford  70.0
# 33                  Wheadon, Mr. Edward H  66.0
# 54         Ostby, Mr. Engelhart Cornelius  65.0
# 280                      Duane, Mr. Frank  65.0

# %%
df.sort_values(["Sex", "Age"], ascending=[True, False])[["Sex", "Name", "Age"]]
#rows organized by the sex column (starting with all females) that are also sorted by age
# Out:
#         Sex                                              Name   Age
# 275  female                 Andrews, Miss. Kornelia Theodosia  63.0
# 483  female                            Turkula, Mrs. (Hedwig)  63.0
# 829  female         Stone, Mrs. George Nelson (Martha Evelyn)  62.0
# 366  female  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.0
# 11   female                          Bonnell, Miss. Elizabeth  58.0
# ..      ...                                               ...   ...
# 839    male                              Marechal, Mr. Pierre   NaN
# 846    male                          Sage, Mr. Douglas Bullen   NaN
# 859    male                                  Razi, Mr. Raihed   NaN
# 868    male                       van Melkebeke, Mr. Philemon   NaN
# 878    male                                Laleff, Mr. Kristo   NaN
#
# [891 rows x 3 columns]

# %%
df.dropna().sort_values(["Sex", "Age"], ascending=[True, False])[["Sex", "Name", "Age"]]
# Out:
#         Sex                                              Name    Age
# 275  female                 Andrews, Miss. Kornelia Theodosia  63.00
# 366  female  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.00
# 11   female                          Bonnell, Miss. Elizabeth  58.00
# 195  female                              Lurette, Miss. Elise  58.00
# 268  female     Graham, Mrs. William Thompson (Edith Junkins)  58.00
# ..      ...                                               ...    ...
# 445    male                         Dodge, Master. Washington   4.00
# 193    male                        Navratil, Master. Michel M   3.00
# 340    male                    Navratil, Master. Edmond Roger   2.00
# 183    male                         Becker, Master. Richard F   1.00
# 305    male                    Allison, Master. Hudson Trevor   0.92
#
# [183 rows x 3 columns]

# %%
df.nlargest(10, "Age")[["Name", "Age"]]
#top 10 values sorted by age, only including name
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0
# 851                   Svensson, Mr. Johan  74.0
# 96              Goldschmidt, Mr. George B  71.0
# 493               Artagaveytia, Mr. Ramon  71.0
# 116                  Connors, Mr. Patrick  70.5
# 672           Mitchell, Mr. Henry Michael  70.0
# 745          Crosby, Capt. Edward Gifford  70.0
# 33                  Wheadon, Mr. Edward H  66.0
# 54         Ostby, Mr. Engelhart Cornelius  65.0
# 280                      Duane, Mr. Frank  65.0

# %%
df.nsmallest(10, "Age")[["Name", "Age"]] #same thing as before for the samllest values
# Out:
#                                 Name   Age
# 803  Thomas, Master. Assad Alexander  0.42
# 755        Hamalainen, Master. Viljo  0.67
# 469    Baclini, Miss. Helene Barbara  0.75
# 644           Baclini, Miss. Eugenie  0.75
# 78     Caldwell, Master. Alden Gates  0.83
# 831  Richards, Master. George Sibley  0.83
# 305   Allison, Master. Hudson Trevor  0.92
# 164     Panula, Master. Eino Viljami  1.00
# 172     Johnson, Miss. Eleanor Ileen  1.00
# 183        Becker, Master. Richard F  1.00

# %% [markdown]
# #### Filtering

# %%
df["Sex"]=="female" #boolean for each row
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df[df["Sex"]=="female"] #filter values for females only
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Age"]>60]
# Out:
#      PassengerId  Survived  Pclass                                       Name
# 33            34         0       2                      Wheadon, Mr. Edward H  \
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
(df["Age"]>60) & (df["Sex"]=="female")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df[(df["Age"]>60) & (df["Sex"]=="female")]
# Out:
#      PassengerId  Survived  Pclass                                       Name
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia  \
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 275  female  63.0      1      0   13502  77.9583    D7        S
# 483  female  63.0      0      0    4134   9.5875   NaN        S
# 829  female  62.0      0      0  113572  80.0000   B28      NaN

# %%
df[(df["Age"]>60) | (df["Age"]<=20)]
# Out:
#      PassengerId  Survived  Pclass                                  Name
# 7              8         0       3        Palsson, Master. Gosta Leonard  \
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 12            13         0       3        Saundercock, Mr. William Henry
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                   ...
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3         Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
condition = (df["Age"]>60) | (df["Age"]<=20)

# %%
df.loc[condition, ["Name", "Sex", "Age"]] #condition and relevant columns
# Out:
#                                      Name     Sex   Age
# 7          Palsson, Master. Gosta Leonard    male   2.0
# 9     Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10        Sandstrom, Miss. Marguerite Rut  female   4.0
# 12         Saundercock, Mr. William Henry    male  20.0
# 14   Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# ..                                    ...     ...   ...
# 869       Johnson, Master. Harold Theodor    male   4.0
# 875      Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 876         Gustafsson, Mr. Alfred Ossian    male  20.0
# 877                  Petroff, Mr. Nedelio    male  19.0
# 887          Graham, Miss. Margaret Edith  female  19.0
#
# [201 rows x 3 columns]

# %% [markdown]
# #### Grouping

# %%
df[["Sex", "Fare"]].groupby("Sex").mean()
# Out:
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df[["PassengerId", "Pclass", "Age", "SibSp", "Parch", "Fare", "Survived"]].groupby("Survived").mean()
#groups survived in shown categories
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
df.groupby("Embarked")["Survived"].count()
#groups embarked and counts the number of the survived
# Out:
# Embarked
# C    168
# Q     77
# S    644
# Name: Survived, dtype: int64

# %%
df[["PassengerId", "Pclass", "Age", "SibSp", "Parch", "Fare", "Survived", "Sex"]].groupby("Sex").mean()
# Out:
#         PassengerId    Pclass        Age     SibSp     Parch       Fare
# Sex
# female   431.028662  2.159236  27.915709  0.694268  0.649682  44.479818  \
# male     454.147314  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
df.groupby("Embarked")["Age"].agg(["count", "mean", "min", "max"])
#only examines special aggregaton functions (here: count, mean, min, max)
# Out:
#           count       mean   min   max
# Embarked
# C           130  30.814769  0.42  71.0
# Q            28  28.089286  2.00  70.5
# S           554  29.445397  0.67  80.0
