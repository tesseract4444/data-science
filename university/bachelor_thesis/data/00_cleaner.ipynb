# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import string
import glob
from pathlib import Path
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import os
from nltk.tokenize import word_tokenize
import spacy

# %%
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1500000

# %% [markdown]
# -----------

# %%
def remove_punctuation(text):
    text = text.replace("’", " ")
    return text.translate(str.maketrans("", "", string.punctuation))

#weitere cleaning-prozesse
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    words = text.lower().split()
    words = [word for word in words if word not in stop_words]
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)


def remove_extra_signs(text):
    text = text.replace("“", "")
    text = text.replace("”", "")
    return text

#zahlen entfernen
def remove_numbers(text):
    text = re.sub(r"\d", "", text)
    text = re.sub(r"\s+", " ", text)
    return text

input_pos = input("Bitte Wortart eingeben (z.B. NOUN, VERB oder ADJ)...").upper()

#wortarten filtern
def pos_filter(text):

    
    #analysieren des texts
    doc = nlp(text)
    
    #extrahieren der substantive
    substantives = [token.lemma_.lower() for token in doc if token.pos_ == input_pos]
    
    #drucken der ergebnisse
    #print(substantives)
    
    #filtern der substantive nach länge
    substantives = [token.lemma_.lower() for token in doc if token.pos_ == input_pos and len(token.lemma_) > 4]
    
    return " ".join(substantives)
# Out:
# Bitte Wortart eingeben (z.B. NOUN, VERB oder ADJ)... verb

# %%
def clean_all(text):
    text = remove_punctuation(text)
    text = preprocess_text(text)
    text = remove_extra_signs(text)
    text = remove_numbers(text)
    text = pos_filter(text)
    return text

# %% [markdown]
# #### Alle Texte verarbeiten

# %%
input_directory = input("Bitte Eingabeverzeichnis einfügen...")
output_directory = "/home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/" + input("Bitte all_words, nouns, adjectives oder verbs eingeben...") + "/" + input("Name Ausgabe-Ordner eingeben...")

#ausgabeverzeichnis erstellen, falls es nicht existiert
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

pattern = os.path.join(input_directory, "*.txt")


for path in glob.glob(pattern):

    with open(path, "r") as file:
        text_raw = file.read()
        text_cleaned = clean_all(text_raw)

        #bereinigte datei in neuem verzeichnis speichern
        output_file = os.path.join(output_directory, f"{os.path.basename(path)}")
        with open(output_file, "w") as file:
            file.write(text_cleaned)

        print(f"Bereinigter Text wurde erfolgreich in die Datei {output_file} gespeichert.")

        print(text_cleaned)
        print(text_cleaned.split()[:10])
# Out:
# Bitte Eingabeverzeichnis einfügen... /home/simon/Dokumente/Uni Würzburg/Digital Humanities/Bachelorarbeit/datasets/my_obama/00_cleaned_files
# Bitte all_words, nouns, adjectives oder verbs eingeben... verbs
# Name Ausgabe-Ordner eingeben... clean_obama
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/november-20-2014-address-nation-immigration.txt gespeichert.
# deliver welcome shape choose break enter watch flout offer exploit reward remain commit begin secure deploy apprehend reflect double start allow passed refuse allow believe solve happen announce build highskille propose generate break believe focus prioritize focus deport track round deport suggest lowpaye spend expect expect reward follow register apply apply apply offer receive leave unfair impossible describe deport enter chance catch disagree understand include become worry believe impugn remember tolerate chance accept compete create reason serve travel include bring start catch watch become landscape clean apply undocumente apply visit deport decide begin advocate strive nation forebear cross welcome teach share create build uphold leave thank bless bless
# ['deliver', 'welcome', 'shape', 'choose', 'break', 'enter', 'watch', 'flout', 'offer', 'exploit']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/september-23-2010-address-united-nations.txt gespeichert.
# challenge share build design unite welcome pursue signal respect devastate affect murder suffer cripple defer interconnect confront pursue begin rescue share renew restart reform begin broaden include emerge resist explore expand remove focus refocus defeat pursue begin target strengthen dismantle deploy pursue pursue embrace reduce strengthen offer extend underscore demonstrate remain choose demonstrate confirm spread confront commit reduce protect unleash embrace pledge recover shake devastate honor commit stand stand pledge travel please pursue recognize divide consider reach commit remain accept choose begin answer strike spare ensure achieve follow believe travel approach improve believe extend believe complete overcome build provide seize understand require allow understand include support promise speak build subject debate slaughter stand front carry achieve posture stand think teach reach address sense drive reflect create confront summon consider build await bring adopt begin state begin exist stand choose enslave anxiety promise abolish smother defer pursue deliver believe close eclipse carry depend include start steal reward recognize offer unleash emerge empower build empower shape assemble insist stand disappear speak march include extend serve promote empower connect embrace monitor guarantee substitute choose determine mistake dictate reflect visit throw establish thrive continue provide imprison celebrate promise kenya progress answer answer build gather bring promote energize strengthen advance protect reinvigorate prevent enforce thrive challenge serve reach suffer speak emerge inspire stand imprison stand stand govern build promise reach claim found remember choose cause cause believe choose access unite thank
# ['challenge', 'share', 'build', 'design', 'unite', 'welcome', 'pursue', 'signal', 'respect', 'devastate']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-10-2017-farewell-address-nation.txt gespeichert.
# crowd prepare leave argue threaten encourage bring thank thank thank follow touch receive agree inspire learn search begin close witness learn happen involve engage believe create selfexecute instrument achieve reach power prepare start follow progress define widen found reverse unleash answer start elect ensure remain realize reflect restore understand require argue quarrel compromise expect require threaten begin shrink determine create determine begin shatter record cover serve amass leave struggle agree unionize avoid achieve create stall intend remain matter frame hardworke undeserve fight withdraw represent zerosum change change understand consider middleage upend listen acknowledge vanish engage practice demand promise remind destroy weaken embrace strengthen start become worship surround challenge increase splinter become start accept represent design prioritize reach admit dispirit elect spend excuse selfdefeate catch halve double solve betray betray guide allowed resist allow build build challenge speak farreache represent think execute remind include destroy threaten serve protect remain guard fight govern reject withdraw expand ignore defend fight increase threaten defeat fight match bring threaten grant throw rebuild reduce insist encourage cater remember happen depend accept happen swinge stand assure write underpin cause preserve reject allow become enter define write examine elect embrace improve share argue organize disappoint elect presume disappoint energize confirm mourn grieve search paralyze regain rebuild remind place bring reward imagine watch believe belong become become display watch start guard think achieve welcome knock breathe leave inspire believe believe embrace carry outnumber believe result serve remain bring write found whisper march reaffirm plant write thank bless continue
# ['crowd', 'prepare', 'leave', 'argue', 'threaten', 'encourage', 'bring', 'thank', 'thank', 'thank']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/february-24-2009-address-joint-session-congress.txt gespeichert.
# discus stress combat distinguish speak watch affect think build weaken shake emerge determine posse require challenge admit understand arrive begin collapse delay compete manage spend shortterm become invest gutte afford arrive revive build bring design begin believe inherit cause worsened assure deliver create rebuild construct expand continue prevent receive begin struggle receive receive extend continue watch understand break promise spend appoint prove create recoverygov spend manage weaken speak affect deposit continue choke begin purchase force suffer break create represent provide launch afford struggle decline bring ensure depend learn provide serve understand comfort attach solve quicken intend receive demonstrate result disappear require result refuse happen understand provide struggle infuriate follow suffer afford govern solve spend reward credit spend secure consign openende ensure happen reform outdate drive punish restore renew compete prepare stand submit solve reflect inherit include afford ignore remind respond prepare create shape supplant catalyze create claim nation invest begin launch invent produce accept carry transform protect marketbase invest develop build speak recognize decisionmake protect retool reimagine compete depend invent address crush cause afford cause provide protect invest reduce bring launch touch include include quality bring achieve bring begin suffer weigh doubt address require industrialize begin finish ensure begin expand continue improve provide prevent create invest expand participate provide afford encourage renew attend children begin ensure agree inherit bring ensure reflect pledge begin eliminate identify eliminate waste increase provide preserve address strengthen begin create suffer commit restore leave include fight review announce allow allow stand ready deploy inspire unyielde serve expand overcome uphold order close capture begin negotiate ignore appoint crush strengthen respond restore avoid escalate demand depend depend stand watch gather govern entrust become consume learn think think destroy rebuild bring rebuild provide think visit teach become persevere cause agree succeed start expect build endure perform carve remember bless bless
# ['discus', 'stress', 'combat', 'distinguish', 'speak', 'watch', 'affect', 'think', 'build', 'weaken']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/february-9-2010-news-conference-congressional-gridlock.txt gespeichert.
# brave understand appreciate continue understand paralyze agree demand think expect transcend press create agree provide agree crumble agree debate spend discuss consider consider restore matter wrangle solve happen support receive cosponsor block create debate accept afford grandstand touch announce measure spend provide report raise continue continue depend hesitate embrace hesitate consider advise position relate confirm obstruct consider afford allow stand wellfunctione plague leave mount respond acknowledge handle affect mention apply struggle indicate start promote think think wrangle agree believe agree believe present accept agree think contaminate think debate think think think indicate agree continue think anticipate start regulation provide think agree protect protect require settle acknowledge business posture think think perpetrate fight mistake travel justify require think biodiesel continue produce develop convert happen include include identify think become assume think provide lowenriche isotope serve reject speak accept indicate posture continue start accept develop indicate isolate indicate approach unify operate pursue forwardleane think solve understand issue lower debate notice become understand happen think phrase refine think consider remind entitle entitle entitle think establish establish establish think establish begin insist believe advocate accomplish understand understand speak think agree eliminate agree agree think include think package build increase provide think yield thank
# ['brave', 'understand', 'appreciate', 'continue', 'understand', 'paralyze', 'agree', 'demand', 'think', 'expect']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/april-15-2010-remarks-space-exploration-21st-century.txt gespeichert.
# thank thank thank thank thank recognize become exclude reach strike visit include remind fight thank participate gather welcome surround launch pilot carry allow decorate propel start launch dumbfound perceive catch create invest declare return touch follow inspire include contribute improve wellbee manufacture think achieve demonstrate inspire arrive capture reach stretch believe compete achieve reach become change start commit broaden continue serve imagine spark launch raise schedule devote worry drive neglect undermine provide outline start increase understand happen institute freeze start issue maintain increase include follow allow increase earthbase improve understand protect extend intend conduct improve improve include reduce reach compete disagree design carry carry orbit continue ensure accelerate establish carry build direct begin develop force become bring readie invest reach develop revise modify finalize begin understand groundbreake allow reach travel tackle farreache pursue require revise include respect charge include consider describe commit think reach reach improve criticize invest groundbreake build complete require expect design allow begin start believe return follow expect repeat challenge learn believe reach operate demand advance ensure point transition compare modernize create compete generate create prime affect become propose develop expect reach prepare write invest farreache provide reach reach learn operate extend fulfil extend reach spend spend solve solve close improve strengthen inspire continue revitalize descend allow solve begin believe begin thank bless bless
# ['thank', 'thank', 'thank', 'thank', 'thank', 'recognize', 'become', 'exclude', 'reach', 'strike']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/september-8-2011-address-congress-american-jobs-act.txt gespeichert.
# continue leave affect watch spend scrape postpone believe reward raise watch stack restore define begin solve drive improve support include provide provide stall invest begin speak start continue write support propose rebuild decay congest watch build build expect deserve modernize instal rehabilitate spend build start attract write support support charge prepare drive belong leave fight spend longterm build highlight collect participate build extend devastate support prolong taken expand allow happen swear raise longterm provide charge release stabilize advocate reduce reform happen prevent realize protect believe raise afford enjoy believe offer eliminate afford bestconnecte invest create reduce decide create afford grandstand choose answer create argue start build create offer improve prevent startup raise refinance burden require outdate affect drive stamp strengthen bring develop create mobilize provide cover learn provide build advance realize believe eliminate agree afford afford order identify require count reject choose expose prevent shortchange reject offer restore dismantle write connect remember mobilize build follow decide build choose spend return include chance decide violate suffer result build build support design allow proclaim decide solve guide start listen intend agree gather remind solve remain thank bless bless
# ['continue', 'leave', 'affect', 'watch', 'spend', 'scrape', 'postpone', 'believe', 'reward', 'raise']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/march-7-2015-remarks-50th-anniversary-selma-marches.txt gespeichert.
# deliver remark follow imagine train attack describe scribble contact comfort stock sewell reverend elect decide clash contest determine triumph examine gather chasten trample splinter march instruct sound plante cover lower march sound reach overcome cross impose elect march endure promise preordain prove remember condemn praise question threaten challenge happen vindicate finish decide behold write found create engage choose reach organize believe believe require singe avoid require speak soweto banish submit change expand serve elect swing march march reassert transcend repay teach teach require afford change understand spawn reject change happen unique sanction cause intimate think change assign change suggest isolate banish complete remain reach bless judge require admit capable write march depend teach build raise build protect march address stunt become accept believe expect expand march design propose sweat weaken crown result gather strike register guess excuse fight shape point endure fashion grant imagine change decide realize break declare endow argue fight brave follow shake reflect huddle yearn survivor build raise organize freshface fight fight spike steal write write truth stand suffer airbrush define respect contain listen unconstraine cross educate singlemost overcome belong improve finish found perfect remember believe bless bless thank
# ['deliver', 'remark', 'follow', 'imagine', 'train', 'attack', 'describe', 'scribble', 'contact', 'comfort']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/march-22-2016-remarks-people-cuba.txt gespeichert.
# deliver thank thank thank thank receive receive receive begin indulge think stand condemn bring unite defeat threaten offer offer carry exert carry build cause cross leave watch settle fight remade extend recognize estrange share colonize build bring trace welcome start blend include combat write compete fight become continue share listen share share believe ignore organize unite emphasize found announce begin normalize establish begin reach restore expand increase welcome acknowledge design believe believe normalize understand believe insist choose believe power unite build begin succeed sustain selfemploye become choose start imitate allow improve realize solve solve begin support encourage bring create outdate burden invest realize continue invest unite depend depend expose reach ignore enable refuse impose depend impose recognize chart remove speak believe believe speak believe agree think believe deserve believe organize criticize include exercise believe believe choose agree agree believe believe cuban disagree point understand raise achieve allow start struggle organize protest debate challenge afford solve concentrate organize voice enjoy consider argue believe progress believe think suggest appeal build appreciate believe unite speak deliver sidebyside stamp believe continue negotiate resolve support examine realize reduce prove achieve continue promote believe foster begin leave stand stand define define sense leave support suggest ignore reject build carry consider rebuild break travel build suffer reach travel recognize recognize embrace sible recognize begin include become realize start leave begin understand listen achieve leave puede
# ['deliver', 'thank', 'thank', 'thank', 'thank', 'receive', 'receive', 'receive', 'begin', 'indulge']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/june-22-2011-remarks-afghanistan-pullout.txt gespeichert.
# continue suffer signal battlefield follow strike route shift launch spend support enter escape regroup order announce reverse openended begin fulfil start bring recover announce start serve recover express replace drain remain inflict increase stabilize begin establish create remain begin strengthen include break believe express protect shape sustain endure ensure target support address endanger continue secure tolerate elude deserve learn enjoy defend wound follow recede serve light learn cause ignore overextend confront chart center embrace pragmatic threaten respond target deploy slaughter choose stand rally grind support protect determine remember found bring adhere respect protect extend stand unwavere deserve anchor spend invest unleash create rebuild recapture share begin build sacrifice provide speak fight stand write forget speak depend trust write found achieve finish cause extend bless bless
# ['continue', 'suffer', 'signal', 'battlefield', 'follow', 'strike', 'route', 'shift', 'launch', 'spend']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/december-1-2009-speech-strategy-afghanistan-and-pakistan.txt gespeichert.
# speak bring prepare stand represent compel hijack strike strike belong distort defile justify harbor seize ravage authorize harbor continue invoke attack endorse destroy protect refuse scatter drive convene establish establish bring wrench repeat cause bring remove leave achieve hardearne deteriorate escape establish elect hamper maintain begin control engage remain serve compare approve announce recognize define disrupt dismantle defeat pledge highranke prevent produce remain overthrow reemerge retain report anticipate volunteer fight deploy define complete insist allow explore involve determine begin seize allow oppose believe exercise consider leave create polarize experience focus rebuild deploy visit wound travel flagdrape return think practice attack speak apprehend commit operate increase believe overarch remain defeat threaten follow reverse strengthen pursue break announce deploy increase create provide fight bleed allow accelerate allow begin execute continue ensure succeed pursue improve provide expect receive support deliver expect focus endure confront understand suffer occupy ground leave prevent spread argue become endanger share define commit build strengthen tolerate provide displace remain unleash create reinforce address suggest stabilize withdraw depend recognize broadbase attack remain effort hamper create acknowledge leave maintain permit prove oppose identify openende commit nationbuilde reject achieve achieve clear fight refuse weigh commit discuss weigh maintain afford ignore approach bring rebuild provide underwrite allow allow openended finish extend endure define involve prevent establish confront count invest capture improve spread understand reject interconnect spend renew forge forge recognize break change believe promote prohibit speak source spill spend rebuild develop develop provide thank underwrite advance found claim continue fight believe summon derive educate spread reality agree sustain navigate allow poison forget begin accept summon believe write carry cause commitment represent thank bless bless thank thank
# ['speak', 'bring', 'prepare', 'stand', 'represent', 'compel', 'hijack', 'strike', 'strike', 'belong']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-20-2009-inaugural-address.txt gespeichert.
# introduce administer touch bring focus stand humble bestow speak water gather carry skill remain generation understand farreache weaken prepare shutter bring threaten lower gather choose strangle remain reaffirm endure choose carry pursue reaffirm understand shortcut settle fainthearte prefer celebrate carry travel settle endure fight struggle sacrifice continue remain begin inventive remain stand protect start begin remake create build restore raise suggest tolerate forget achieve shift consume apply manage spend reform restore expand remind prosper depend reach extend reject found imagine draft expand watch endure understand protect cause temper guide understand begin leave forge hardearne lessen apologize waver induce slaughter broken outlast shape taste emerge believe dissolve reveal usher judge silence extend starve enjoy afford suffer consume change change consider unfold remember embody inhabit faith break decide depend demand require accept seize satisfy define serve travel huddle abandon advance stain outcome doubt order survivethat alarm remember refuse carry deliver thank bless bless
# ['introduce', 'administer', 'touch', 'bring', 'focus', 'stand', 'humble', 'bestow', 'speak', 'water']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/july-24-2013-remarks-education-and-economy.txt gespeichert.
# deliver bring celebrate figure confuse watch tempt think repeat understand participate sweep offer reward happen begin begin struggle combine quadruple budge begin stack paper leverage fight break invest double change benefit bless create surge produce produce happen manufacture poise batter start build tread reverse build solve start reduce ignore recognize suggest start provide create provide solve think involve require focus prepare manufacture stand think involve build threeyear conspire understand allow happen happen grandkid focus prepare happen talente train happen throw think encourage increase reduce reduce learn prove happen prepare prove require announce connect happen access succeed learn happen affect deserve reverse double happen happen borrow repay invest start prioritize skyrocket statefunde enroll happen partner allow begin involve create graduate happen shake mortgage happen tackle create establish decide reach reach reach involve shoot bring share think threaten manage shake promise start generate pursue inspire inspire inspire continue leave struggle thank bless bless
# ['deliver', 'bring', 'celebrate', 'figure', 'confuse', 'watch', 'tempt', 'think', 'repeat', 'understand']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/may-19-2011-speech-american-diplomacy-middle-east-and-north.txt gespeichert.
# speak thank thank begin thank travel approach believe witness demand follow drive strengthen follow define remove break begin bring continue offer reject focus destroy build begin mohamme devastate confiscate happen refuse douse light speak think refuse refuse leave follow represent choose apply bless reach start grievance blame become manipulate provide allow connect organize emerge breathe chant explain shout achieve accomplish expect resolve reach change unfold pursue counter spread secure safeguard stand pursue continue believe believe cripple acknowledge allow speak speak fester pursue hostagetake threaten deepen begin broaden believe believe offer build doubt change peril promise accept pursue proceed launch determine follow shortterm speak guide oppose include choose support translate support promote begin extend answer launch promise prevent perpetrate learn impose wellintentione organize force proceed remain choose condemn include announce demand shoot allow release allow start challenge isolate follow speak stand repress remember brutalize throw continue insist deserve acknowledge react outline commit insist create participate reject favor poise continue stand encourage acknowledge speak believe build broaden reach shape continue build expand intend provide include sanction speak listen support support depend respect disagree disagree embrace oppose restrict depend respect build suffer succeed worship destroy empower continue insist apply focus teach start stand reach prevent achieve promote promote support transition provide change close leave channel solidify trigger depend broadbase learn think model generate ensure promote integrate start modernize recover elect saddle invest regain guarantee steal create invest model support launch provide export build exist promote adopt construct serve create require steal become distribute develop increase conclude relate teach suffer bring continue grind stalemate argue involve delegitimize isolate create achieve insist realize exist share share advance defend undergo believe produce fulfil impose involve state enjoy negotiate result believe agree recognize establish govern reach defend robust provide phase coordinate nonmilitarize agree demonstrate provide resolve wrench remain provide resolve recognize begin raise provide continue recognize harden start bring realize recognize expect define serve chant threaten gather celebrate grant claim scene unsettle drive found fight extend enslave stand organize protest declare create guide transform endow accompany found govern hesitate reach bring thank
# ['speak', 'thank', 'thank', 'begin', 'thank', 'travel', 'approach', 'believe', 'witness', 'demand']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/august-31-2010-address-end-combat-mission-iraq.txt gespeichert.
# rebuild endure midst reach serve serve intend strengthen announce begin change become threaten wound encounter shift serve serve complete defeat terrorize fight seize shift train embrace remain announce pledge announce bring strengthen remove close transfer complete continue suffer begin fight remove encourage doubt remain advise assist support target protect strengthen resolve displace deliver visit reflect achieve reject understand build provide spend persevere belief speak disagree support oppose ground learn confront challenge support attack speak continue remain anchor defeat prevent serve apply capture order fight break provide train support begin determine begin openende include project recognize exist limitles emerge begin expand begin promote understand understand anchor spend finance borrow shortchange contribute manufacture result tackle challenge sense serve fight await reach deserve compete create unleash allow serve maintain serve serve treat provide pursue fight include become chance apply expand stand fight journey predawn fight shoot leave begin serve endure begin fight serve fight stare fight travel bless bless serve
# ['rebuild', 'endure', 'midst', 'reach', 'serve', 'serve', 'intend', 'strengthen', 'announce', 'begin']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/may-25-2011-address-british-parliament.txt gespeichert.
# deliver thank thank begin reaffirm share analyze overanalyze strain share share reign spell develop establish settle expand propel forge invest elect gather begin inspire rabblerouse enshrine perfect persecute learn stand speak fight defend sacrifice found ensure forge expand include build begin arrive stand recover remove remove break begin disrupt enter share stretch require ensure spread dismantle spread determine reshape create become decline represent shape emerge thrive remain require remain define fortify offer share believe afford stand solve agree require build adapt remake begin remain unleash begin arise marketbase embrace favor freethinke forwardlooke maintain renew educate remind protect establish contain begin infect prevent build achieve leave recognize cripple strike express deserve dignify reason ensure consume consume require require believe serve emerge pollute produce safeguard confront fight forget build deter stand confront remember focus defeat learn fight continue defend stalwart fight serve sacrifice enjoy break build prepare transition pursue ensure effort revitalize continue allow build churchill share maintain share spread strengthen account strive share resolve threaten choose stand empower allow thrive confront allow innovate allow reach believe believe guide fight mobilize reach leave tunis grant impose subject stand invest start deepen demonstrate bring stand pursue strengthen support overcome enjoy acknowledge endure fight perfect protect insist reject offer carry threaten libya protect proceed dictate impose stand believe cause abide believe define belong believe believe debate recognize unite divide change serve define reach differ remember reach claim waver defend endow forge hardheade share battlefield share speak march endure cause thank
# ['deliver', 'thank', 'thank', 'begin', 'reaffirm', 'share', 'analyze', 'overanalyze', 'strain', 'share']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/march-15-2010-speech-health-care-reform.txt gespeichert.
# bring introduce thank understand understand happen selfemploye provide diagnose increase raise maintain figure shift charge raise spend happen afford realize build surrender insure force include understand think understand realize chase collapse perform diagnose expect force terrify think argue focus preexist force choose believe start think think worry think worry happen faint faint think think preexist think start happen forbid diagnose insure problem happen happen happen happen plunge happen double think afford sustain happen debate agree describe incorporate think replace believe provide raise segment control believe control build interfere change preexist preexist require offer start catch start receive surprise become uninsure change become happen estimate afford watch understand squeeze afford provide spend spend spend eliminate stand expand expand expand bring raise estimate incorporate contain medicare costcutte reduce bring determine remember guess close stick reduce eliminate spend guarantee believe handwringe touch solve solve relieve contribute provide happen bless bless
# ['bring', 'introduce', 'thank', 'understand', 'understand', 'happen', 'selfemploye', 'provide', 'diagnose', 'increase']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/september-6-2012-nominee-acceptance-speech-2012-democratic.txt gespeichert.
# accept thank thank thank thank thank thank remind thank accept address speak leave wonder become become advertise build defend drive triumph share promise reward begin shadow start struggle collapse fight think offer believe bring believe believe expand pretend offer elect build require share pursue carry remember remedie dictate solve choose rebuild choose outsource define borrow build build bring stamp create start reward create choose create happen choose choose raise double build longlaste progress write collect offer offer invest build develop choose support continue reduce choose compete answer raise learn waste decide defer crumble inspire instill learn promise recruit improve learn choose choose prove promise promise attack blunt serve respect forget sustain serve serve fight strengthen forge spread reassert stand advance remain disrupt contained waver pursuit sweep define reach bluster blunder stick visit insult spend spend rebuild nationbuilde choose reduce stick believe reform create spend refuse refuse raise refuse start eliminate medicare spend retire reduce promise strengthen afford release start borrow believe endow insist celebrate entitle drive believe found accept believe build believe trick protect believe offer become refuse think solve think understand recognize believe change limit think afford pledge deport serve fight happen decide marry control happen change speak change share achieve stand close build understand build recover cause amputate watch serve remember watch wound sparkle inspire begin travel belong define promise reserve heard beholden stand believe provide believe promise travel leave learn bless thank bless bless
# ['accept', 'thank', 'thank', 'thank', 'thank', 'thank', 'thank', 'remind', 'thank', 'accept']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-20-2015-2015-state-union-address.txt gespeichert.
# deliver touch unfold fight spread create graduate insure serve remain serve humble endure require shrink bustle write accept commit generate stand defeat allow propel begin write happen worsen enrol retrain sacrifice write represent scrimp sacrifice retool think stand promise rebuild emerge believe reverse create believe reduce bring believe prepare believe prevent encourage taxpayerfunde bailout protect crush double verdict expand continue unravel refighte touch start raise restore splurge hardworke adapt protect share contribute require afford lower workforce provide nicetohave treat treat create think adopt leave refuse raise believe hardestworke raise recognize invest weaken leave thrive train catch reward require strive price choose start graduate spread become burden reduce biden connect highpaye offer higherpaye defend ensure slash launch churn combine exist generate build train agree create include fastestgrowe happen write protect break bring eliminate deliver reverse think launch bring personalize protect reach build reshape unleash convert create launch reenergize prepare begin instagram reward rebuild bring allow avoid accumulate achieve achieve hardworke goodpaye maintain believe teach separate react believe combine stand target continue learn train honor support include include destroy support assist stand require uphold oppose support reassure impose reinforce suggest stand isolate remove stand extend begin overjoy belong reduce negotiate prevent nucleararme include avoid prevent guarantee alienate maintain ensure start threaten expect intend consume integrate evolve protect leave unleash prouder build spread invest change continue produce endanger determine drive commit limit offer reach protect threaten prohibit constrain speak resurface continue reject advocate condemn spend condemn fight promise increase strengthen build strive share point deliver divide misguide benefit think believe believe believe mourn grieve watch drive bighearte expect serve serve react break imagine understand embrace appeal demonize spend drown sense debate agree choose agree strive agree hardworke snatch uphold agree understand harass understand marry agree start protect start rebuild deserve swear believe share outline disagree agree commit reflect shortcome unite commit improve commit value begin remake begin start thank bless bless
# ['deliver', 'touch', 'unfold', 'fight', 'spread', 'create', 'graduate', 'insure', 'serve', 'remain']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/february-7-2009-remarks-american-recovery-and-reinvestment-act.txt gespeichert.
# thank begin thank process thank thank elect accept climb begin begin pretend constitute begin begin create begin provide begin diverse include udall deserve thank start prove chairman happen balance provide create include neglect bring build remake build rebuild crumble repair bring upgrade improve outeducate create provide continue pursue create reach spiral crush modernize computerize reduce continue longdelaye extend control create produce think provide expand result carry support deliver create allow slash weatherize connect represent understand spark compose include prevent swear include hardworke benefit ensure implement assure assign ensure invest spend receive expect create spend create create represent launch become recognize build thrive recognize inherit begin restore explode slippage demand rever continue leave struggle convert emerge write thank thank
# ['thank', 'begin', 'thank', 'process', 'thank', 'thank', 'elect', 'accept', 'climb', 'begin']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-28-2014-2014-state-union-address.txt gespeichert.
# deliver spend create finetune prepare afford bonetire dream remember speak represent rebound produce happen declare betterpositione question hinder consume found carry threaten commit rebuild believe produce invest bring leave create create believe unite suffer eliminate weaken depend budge deepen stall happen agree offer strengthen build require stand expand bring improve reduce launch encourage organize reduce hardworke believe depend define start intend think insource argue riddle invest create create rebuild unclog protect finish slash streamline permit chance manufacture launch raleigh announce double entrepreneur create create protect stamp surrender federallyfunde allow bring announce extract invest build build sustain strengthen protect become pound outsource continue progress increase partner reduce rescue build drive create reduce change struggle direct allow happen require settle leave break create outline create rapidlychange bestselle flood experience connect design concentrate prove convince return reform expire employ collect husband claim write write depend build hardworke shoot support prepare guarantee support crowd cheer raise prepare solve require challenge demand think reach reach repeat raise invest decide elect pledge start connect offer shake offer price offer reach color reach enter deserve deserve sacrifice deserve belong deserve believe succeed succeed stifle understand resent achieve agree raise raise raise raise boost follow raise intend boost reduce require federallyfunde reach stand spend involve reduce agree strengthen double create start encourage build guarantee upsidedown offer protect expose hardworke break preexist cover meant preexist charge lower expect refighte increase cover friend deserve cover pursue pursue stand weaken strengthen appoint offer drive stand intend visit serve agree serve support unify negotiate remain carry assist change resolve remain evolve strengthen invest succeed remain believe depend protect hesitate allow fight fight prefer pursue target impose believe depend violate remain counter remain depend include rally prevent allow reduce eliminate continue deserve speak support achieve begin eliminate enrich instal verify build engage achieve prevent obtain succeed cleareye support threaten agree convince build negotiate negotiate threaten succeed seize stand build resolve remember define understand expand position remain support build stand express bring build expand continue focus devastate batter greet forget bless promote believe bring serve return slash receive receive include continue endure gruele blind struggle support learn serve stumble discourage place create build promote share plant believe bless bless
# ['deliver', 'spend', 'create', 'finetune', 'prepare', 'afford', 'bonetire', 'dream', 'remember', 'speak']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/june-4-2009-address-cairo-university.txt gespeichert.
# underlie pursue thank honor stand represent carry greet assalaamu include conflict treat bring exploit continue breed define achieve overlap progress recognize happen bring sustain listen learn speak humble share drive include spend break carry learn develop algebra print spread cherish demonstrate recognize write found enrich fight serve stand start teach excel build light elect found reveal consider fight appear apply selfintereste progress found create struggle shape dedicate elect exist include enjoy protect doubt share recognize begin understand share learn weaken infect pursue operate endanger slaughter embrace record subjugate selfdefeate elevate think dealt share ignore suggest speak believe confront confront confront reject protect demonstrate pursue question justify victim choose claim reach debate bring determine partner involve weaken teach endure combat promote solve invest displace provide develop depend address provoke believe believe remind build teach forge leave pursue order elect remove remove train develop tolerate alter forget provoke prohibit order close threaten isolate persecute culminate enslave torture threaten repeat prevent deserve suffer endure endure stalemate bring found pursue outcome require agree abandon suffer sleep claim surrender build develop serve hamas recognize fulfil unify recognize recognize exist acknowledge continue violate achieve ensure develop continue serve continue progress recognize cause develop sustain recognize choose selfdefeate impose recognize intend muhamme share define elect remain prepare overcome proceed discus reach prevent understand choose reaffirm include abide connect impose reflect ground presume presume outcome yearn govern steal choose realize promise succeed disagree welcome elect provide advocate suppress matter maintain respect place legitimate thank address worship choose thrive challenge disturb upheld maronite close examine commit avoid impede practice dictate disguise bring forge bring abdallah combat provide reject choose cover believe educate issue issue struggle continue convince contribute allow reach order choose support expand pursue microfinance bring offensive bring include bring maintain dubai sustain enjoy begin recognize remain emphasize focus expand bring encourage promise invest learn create communicate create identify launch transfer marketplace create appoint develop create announce expand promote pursue describe threaten serve respect achieve begin suggest clash occur build reimagine focus commit sustain start choose transcend pulse bring write create promote bless thank thank
# ['underlie', 'pursue', 'thank', 'honor', 'stand', 'represent', 'carry', 'greet', 'assalaamu', 'include']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/march-21-2013-address-people-israel.txt gespeichert.
# visit deliver thank thank receive bring reaffirm witness shine originate speak bring scrutinize begin celebrate enjoy bring wander become suffer inspire include cross start emerge reach carry weather speak yearn express accept promise carry journey promise involve suffer sustain achieve dream believe deserve demonstrate reach promise begin welcome build broaden reach establish thrive spirit understatement achieve overcome bring build begin recognize explain recognize believe build share share advance strengthen share extend transcend strengthen enrich govern define allow recognize define emerge matter believe believe arrange begin exercise retain measure think consider consider think invest deserve accept stand defend expect recognize think think board raise tolerate continue cooperate transfer relinquish begin depend establish protect think consider think nucleararme challenge include nucleararme raise undermine spark embolden build increase isolate divide believe resolve ensure forsake resolve remain pursue require contain achieve prevent press reject exist ensure change think sense surround reject accept grant adhere reject reject mistake question bring begin reach withdraw extend confront believe understand increase achieve press agree recognize underlie believe believe express decide consider believe endure involve protect inflict pronounce understand resolve respond progress begin sideline question center receive oppose recognize restrict build believe succeed believe listen believe determine remember define quote insist fulfil think describe approach expect negotiate believe believe build maintain imagine include reject achieve bring guarantee avoid provide exhaust grind focus adapt change condemn normalize recognize insist recognize viable suggest believe think build stand marry yearn begin design promise create accomplish build learn learn overcome inherit recognize drive drown light believe protect accept remember believe recognize learn bring define create produce change startup bring reach trade create reshape bring learn start speak happen yearn start connect thrive center believe enhance enhance build imagine reconnecte understand follow remind carry found claim count inspire repair bless bless bless thank
# ['visit', 'deliver', 'thank', 'thank', 'receive', 'bring', 'reaffirm', 'witness', 'shine', 'originate']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/may-1-2011-remarks-death-osama-bin-laden.txt gespeichert.
# deliver laden result united announce conduct darken collapse billow heartbreak force leave offer offer wound reaffirm unite unite bring commit learn carry declare commit disrupt strengthen remove include avoid escape continue operate operate direct continue brief develop locate determine authorize bring launch carry avoid continue defeat continue remain reaffirm slaughter include welcome believe declare order speak agree choose start wound understand tolerate threaten stand achieve carry forget waver prevent think prevail cause secure remind struggle remember bless bless
# ['deliver', 'laden', 'result', 'united', 'announce', 'conduct', 'darken', 'collapse', 'billow', 'heartbreak']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-25-2011-2011-state-union-address.txt gespeichert.
# ...
# deliver thank thank begin thank include eloquent understand survivor mourn raise thank connecticut perform learn inherit shake shake prevent happen decide change notice refer change wonder leave flicker gather happen speak impact forget grieve comprehend mobilize organize elect determine elect respond protect happen happen elect happen share shoot include decide protect protect contradict protect announce reduce consider remember begin debate reduce appreciate require happen think strengthen struggle debate support deserve consider check convict restrain commit arrest avoid expect commit convict think think agree agree stand agree think happen think suppose agree float think prevent happen defeat happen deserve stand applaud deserve deserve begin drown teach stand stand believe believe divide believe watch think think listen infringe learn agree happen think think people understand drive understand realize experience think suppose shoot suppose suppose exercise worship exercise reconcile divide prevent engage involve listen stand agree protect murder fight happen respond expect expect believe believe believe believe think prevent deserve arrive raise convince bless bless
# ['deliver', 'thank', 'thank', 'begin', 'thank', 'include', 'eloquent', 'understand', 'survivor', 'mourn']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/september-9-2009-address-congress-health-care.txt gespeichert.
# barack defend propose include preexist insure reform speak thrive build determine attempt introduce continue begin understand place welfare selfemploye afford decide allow happen happen report delay cancel declare reinstate double heartbreake treat spend force aspire afford compete place skyrocket spend combine reform leave believe restrict provide employerbase leave represent disrupt represent believe build build offer achieve develop complete announce happen support oppose disdain unyielde offer shortterm solve reign bring deliver deliver announce provide provide include incorporate require require preexist receive limit charge break require cover catch expect offer start create compete afford price provide abide mention preexist offer become propose embrace provide company refuse provide require cover preexist achieve require carry require carry require offer cover afford exempt afford avoid improve remain believe exist outline allow afford benefit spread realize spread claim insure propose apply remain attack oppose allow choose sponsor administer guide control control treat cherrypicke overcharge profitable testify encourage reward provide mention option insurance force choose impact believe argue compete subsidize insist selfsufficient avoid provide provide inhibit favor propose leave remind drive remain accomplish address example suggest provide propose explore issue prove require spend promise materialize estimate exist hardearne spend speak medicare subject stand remain eliminate subsidy improve create charge identify ensure promise spread fight support privatize happen watch deliver offer encourage reduce encourage reduce stand provide support accord insist reform bring believe contribute propose focus practice consider authorize think direct propose spend begin spend spend exist realize reduce propose incorporate continue listen improve stand accept happen succeed suffer receive write deliver speak express repeat remind write think selfreliance figure source represent drive provide provide stricken forget afford regard stand reward deliver support argue stand argue represent enter understand solve understand understand match leaven exploit craft attack throw engage matter solve remain understand understand believe believe believe replace believe bless bless
# ['barack', 'defend', 'propose', 'include', 'preexist', 'insure', 'reform', 'speak', 'thrive', 'build']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/april-28-2010-remarks-wall-street-reform.txt gespeichert.
# deliver thank thank elect thank defend speak force postpone start force shrink satisfied claim recover incumbent rebuild address place bring speak unfold follow happen outcome believe believe raise happen forget trade happen speak build continue shift update ensure protect achieve debate represent speak fight believe explain consider create protect begin respond bring ensure protect maintain protect design contain interconnect begin happen employ hurry deploy propose recover insist ensure propose encourage claim bailout avoid taxpayerfunde create ensure threaten bring enact instill depend trust enact ensure continue bring force bring confuse understand charge oversee place ensure allay manage hedge interest suppose operate accrue threaten design respect prevent ensure trade charge encourage continue highlyleverage propose enact result afford mislead exploit start stifle stifle empower compete confuse compete offer depend award determine place present offend create contribute bring protect descend design weaken wither produce believe agree choose unfettere stymie tension allow manage debate found allow change apply ensure remain remain debate allow think illustrate wildeye stare rivet consider reduce appear cause secure design achieve ensure speak divide interest thank bless bless
# ['deliver', 'thank', 'thank', 'elect', 'thank', 'defend', 'speak', 'force', 'postpone', 'start']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/june-26-2015-remarks-eulogy-honorable-reverend-clementa.txt gespeichert.
# deliver honor receive promise welcome admit remember believe believe persevere receive promise believe deliver follow charleston claim notice smile reassure remark enter arrive anoint spread expand teach exhibit represent sprawl place neglect wrack discourage fortify reverend embody conduct encourage happen remember choose reside embody isolate think eulogize godfeare persevere share happen center serve worship gather shout continue organize teach happen inviolate build happen preach begin sense terrorize imagine incite presume deepen trace blind allege surround invite allege anticipate respond allege imagine charleston respond bighearte blind comprehend understand reflect preach describe accord merit deserve grace manifest visit allow prove confederate acknowledge include subject acknowledge represent remove insult acknowledgment fight cause expression transform goodwill strive think continue tragedy dilapidate cause soften catch infect serve realize infect realize guard guard consider recognize treat inflict change traumatize happen happen place acknowledge respect express deserve choose receive expect happen believe prevent continue require betrayal stand believe allow deliver avoid infect settle follow express disagree listen wellpractice understand depend justify avoid repeat break involve change grace continue
# ['deliver', 'honor', 'receive', 'promise', 'welcome', 'admit', 'remember', 'believe', 'believe', 'persevere']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/august-28-2008-acceptance-speech-democratic-national.txt gespeichert.
# barack accept express accompany travel embody thank stand share achieve pursue ensure pursue stand promise jeopardy define threaten watch afford drive afford respond break explain bring stand doubt gratitude break deliver think change write suffer become count leave believe think define propose offer benefit privatize subscribe discredit trickle constitute progress watch receive progress create start stand march reward raise listen remember stand fight close start teach watch think shape intend promise treat drive create solve protect provide invest ensure willing spell reward write deserve start create eliminate create raise understand invest build afford invest outsource provide compete chance invest commit serve afford watch discriminate leave choose protect protect promise close eliminate admit fulfil require require renew recover provide admit replace provide essence promise serve stand oppose distract argue attack follow learn wallow stand misguide grasp defeat operate occupy protect deter stand strain follow defend squander build hesitate finish fight rebuild renew prevent obtain build defeat restore yearn debate suggest disagree challenge agree serve fight bleed serve serve require measure agree agree reduce plague uphold agree deserve separate undercut unite dismiss expect record settle realize spend understand stand understand expect teach define happen demand insist believe provide involve think promise travel reach bring stand speak gather defer march educate rebuild protect pledge promise waver thank bless bless
# ['barack', 'accept', 'express', 'accompany', 'travel', 'embody', 'thank', 'stand', 'share', 'achieve']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/october-21-2011-remarks-end-war-iraq.txt gespeichert.
# announce return pledge bring strengthen announce remove ensure announce remove speak reaffirm speak forge promise cross stand agree coordinate invite endure unleash contribute insist continue train offer continue build homecome reunite reflect serve wound reflect recede allow achieve include remove begin bring begin deploy continue shape build bring welcome include enlist create build restore restore thank
# ['announce', 'return', 'pledge', 'bring', 'strengthen', 'announce', 'remove', 'ensure', 'announce', 'remove']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/june-15-2010-speech-bp-oil-spill.txt gespeichert.
# respond rebuild touch exist return speak assault drill injure begin limit assemble prizewinne provide direct mobilize finish expect spill cause recover happen charge respond contain respond authorize clean affect remove absorb approach approve implement continue offer perfect arise cause matter focus affect start wrench happen require control ensure administer compensate restore represent suffer disappear recover respond develop design ensure happen approve consider place deserve establish understand cause offer issue create allow continue expect begin regulate issue become allow shower allow become bring build learn drill improve drill entail drill drill number require block invest threaten menace consign unfold embrace seize speak instal discover create accelerate associate believe afford tackle suggest raise believe wonder spend boost deserve accept settle challenge produce surface refuse limit define found sustain sustain begin shrimp bring begin promise grant unyielde await guide thank bless bless
# ['respond', 'rebuild', 'touch', 'exist', 'return', 'speak', 'assault', 'drill', 'injure', 'begin']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-12-2011-remarks-memorial-victims-tucson-az-shooting.txt gespeichert.
# speak thrive thank gather stand mourn dwell break gather fulfil envision answer carry update shatter represent serve recommend appoint become describe hardestworke attend decide survive marry travel enjoy return revolve volunteer start widow retire spend sacrifice deserve survive decide bless participate break break reason survive include fight speak allow leave decide tackle wrestle remind remind require summon require debate polarize think happen happen trigger shoot examine passive discus point assign expand listen shake force reflect spend force reflect question remind believe abide prize embody participate deserve deserve pointscore strive discuss remember cause question widen believe believe believe believe treat believe divide believe believe imagine become begin start shape elect grant imagine imagine mention picture commit forge bless bless
# ['speak', 'thrive', 'thank', 'gather', 'stand', 'mourn', 'dwell', 'break', 'gather', 'fulfil']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-29-2013-remarks-immigration-reform.txt gespeichert.
# speak thank thank start thank thank mention solis prouder swear define require settle ignore require require debate dwindle emerge agree break strive strengthen think define build start create create startup found include break strengthen break cross overstay dispute contribute weave offer happen follow break threaten commit strengthen provide bring effect leave think start study start study start create patch strengthen endanger bring build pursue consider offer announce propose campaign encourage follow allow bogge debate provide propose support engage place insist believe continue crack figure implement allow verify agree clear include learn bring reflect pursue start succeed create strengthen continue believe believe moment become issue enflame become happen forget forget remember bring immigrate leave arrive huddle arrive raise build build remember build found write bring pledge watch drive matter emerge approve accept become build build become become remember remember welcome aspire bless bless
# ['speak', 'thank', 'thank', 'start', 'thank', 'thank', 'mention', 'solis', 'prouder', 'swear']
# Bereinigter Text wurde erfolgreich in die Datei /home/simon/bachelorarbeit/vergleich_mk_trump/cleaned_docs/verbs/clean_obama/january-12-2016-2016-state-union-address.txt gespeichert.
# deliver shake understand achieve appreciate battle surprise learn write personalize believe protect raise matter hardworke reshape connect broaden widen accelerate influx fight expand claim promise threaten adhere think extend emerge ensure recover reform reinvent deliver secure stand believe answer solve become reflect start create threequarter claim decline peddle change start replace automate locate concentrate squeeze start trend offend agree agree require goodpaye leave increase boost build provide offer hardworke stick reduce provide fight start provide bounce understand retool retrain weaken strengthen employerbase launch coverage create become guess agree improve hardworke encourage tackle welcome expand believe thrive think change allow cause return watch avoid believe startup figure spread bring argue build nurture protect launch start announce develop debate agree intend solve produce listen result employ accelerate subsidize invest manage reflect impose build happen protect create preserve deserve isolate spend combine stand elect begin diminish threaten contract build struggle protect include destroy claim twist threaten representative destroy support reclaim authorize learn focus continue become solve rebuild spill weaken learn discipline mobilize break pursue build principle prevent nucleararme speak avoid spread allow forge support enforce isolate promote restore position improve recognize ignore occupy unravel rally nation protect resolve strengthen depend prevent reach depend target matter stand imitate vandalize diminish achieve begin recognize insist perfect bring happen happen happen agree distribute expect argue require think disagree think weaken grind contest agree break bridge elect worstkept enjoy address change change reflect think reduce exist raise modernize participate intend change elect elect happen depend suggest elect believe forsake allow fight produce contradict believe prefer support fight depend stand stand reflect inspire travel believe travel unfold clock serve dream start determine treat override teach believe count cleareye bighearte believe stand bless bless
# ['deliver', 'shake', 'understand', 'achieve', 'appreciate', 'battle', 'surprise', 'learn', 'write', 'personalize']
